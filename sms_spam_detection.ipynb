# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix

# %%
df = pd.read_csv(r'C:\Users\THANK YOU\OneDrive\Desktop\sms_spam_detection\spam.csv', encoding='latin-1')

# %%
df = df[['v1', 'v2']]
df.columns = ['label', 'text']

# %%
df['label_num'] = df['label'].map({'spam': 1, 'ham': 0})

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df['text'], df['label_num'], test_size=0.2, random_state=42
)

# %%
vectorizer = CountVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)   
X_test_vec = vectorizer.transform(X_test)

# %%
model = MultinomialNB()
model.fit(X_train_vec, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test_vec)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.9838565022421525
# Precision: 0.9852941176470589
# Recall: 0.8933333333333333
# Confusion Matrix:
#  [[963   2]
#  [ 16 134]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

model = MultinomialNB()
model.fit(X_train_vec, y_train)
y_pred = model.predict(X_test_vec)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.9623318385650225
# Precision: 1.0
# Recall: 0.72

# %%
pip install fastapi
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fastapi
#   Downloading fastapi-0.138.1-py3-none-any.whl (129 kB)
#                                               0.0/129.2 kB ? eta -:--:--
#      ------------------------------------   122.9/129.2 kB 2.4 MB/s eta 0:00:01
#      -------------------------------------- 129.2/129.2 kB 1.9 MB/s eta 0:00:00
# Collecting starlette>=0.46.0 (from fastapi)
#   Downloading starlette-1.3.1-py3-none-any.whl (73 kB)
#                                               0.0/73.6 kB ? eta -:--:--
#      ---------------------------------------- 73.6/73.6 kB 4.2 MB/s eta 0:00:00
# Collecting pydantic>=2.9.0 (from fastapi)
#   Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# Collecting typing-extensions>=4.8.0 (from fastapi)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Collecting typing-inspection>=0.4.2 (from fastapi)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic>=2.9.0->fastapi) (0.6.0)
# Collecting pydantic-core==2.46.4 (from pydantic>=2.9.0->fastapi)
#   Using cached pydantic_core-2.46.4-cp311-cp311-win_amd64.whl (2.1 MB)
# Collecting anyio<5,>=3.6.2 (from starlette>=0.46.0->fastapi)
#   Downloading anyio-4.14.1-py3-none-any.whl (124 kB)
#                                               0.0/124.9 kB ? eta -:--:--
#      ----------------------------------     112.6/124.9 kB 6.4 MB/s eta 0:00:01
#      -------------------------------------- 124.9/124.9 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.8 in c:\programdata\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi) (3.4)
# Installing collected packages: typing-extensions, annotated-doc, typing-inspection, pydantic-core, anyio, starlette, pydantic, fastapi
# Successfully installed annotated-doc-0.0.4 anyio-4.14.1 fastapi-0.138.1 pydantic-2.13.4 pydantic-core-2.46.4 starlette-1.3.1 typing-extensions-4.15.0 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script fastapi.exe is installed in 'C:\Users\THANK YOU\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-server 1.23.4 requires anyio<4,>=3.1.0, but you have anyio 4.14.1 which is incompatible.

# %%
from fastapi import FastAPI
from pydantic import BaseModel
import joblib

app = FastAPI()
model = joblib.load('spam_model.pkl')
vectorizer = joblib.load('vectorizer.pkl')

class Message(BaseModel):
    text: str

@app.post("/predict")
def predict(msg: Message):
    vec = vectorizer.transform([msg.text])
    pred = model.predict(vec)[0]
    return {"spam": bool(pred)}
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from fastapi import FastAPI
#       2 from pydantic import BaseModel
#       3 import joblib
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fastapi\__init__.py:7
#       3 __version__ = "0.138.1"
#       5 from starlette import status as status
# ----> 7 from .applications import FastAPI as FastAPI
#       8 from .background import BackgroundTasks as BackgroundTasks
#       9 from .datastructures import UploadFile as UploadFile
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fastapi\applications.py:7
#       4 from typing import Annotated, Any, Literal, TypeVar
#       6 from annotated_doc import Doc
# ----> 7 from fastapi import routing
#       8 from fastapi.datastructures import Default, DefaultPlaceholder
#       9 from fastapi.exception_handlers import (
#      10     http_exception_handler,
#      11     request_validation_exception_handler,
#      12     websocket_request_validation_exception_handler,
#      13 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fastapi\routing.py:43
#      41 from annotated_doc import Doc
#      42 from anyio.abc import ObjectReceiveStream
# ---> 43 from fastapi import params
#      44 from fastapi._compat import (
#      45     ModelField,
#      46     Undefined,
#      47     lenient_issubclass,
#      48 )
#      49 from fastapi.datastructures import Default, DefaultPlaceholder
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fastapi\params.py:7
#       4 from enum import Enum
#       5 from typing import Annotated, Any, Literal
# ----> 7 from fastapi.exceptions import FastAPIDeprecationWarning
#       8 from fastapi.openapi.models import Example
#       9 from pydantic import AliasChoices, AliasPath
#
# File ~\AppData\Roaming\Python\Python311\site-packages\fastapi\exceptions.py:5
#       2 from typing import Annotated, Any, TypedDict
#       4 from annotated_doc import Doc
# ----> 5 from pydantic import BaseModel, create_model
#       6 from starlette.exceptions import HTTPException as StarletteHTTPException
#       7 from starlette.exceptions import WebSocketException as StarletteWebSocketException
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pydantic\__init__.py:5
#       2 from typing import TYPE_CHECKING
#       3 from warnings import warn
# ----> 5 from ._migration import getattr_migration
#       6 from .version import VERSION, _ensure_pydantic_core_version
#       8 _ensure_pydantic_core_version()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pydantic\_migration.py:4
#       1 import sys
#       2 from typing import Any, Callable
# ----> 4 from pydantic.warnings import PydanticDeprecatedSince20
#       6 from .version import version_short
#       8 MOVED_IN_V2 = {
#       9     'pydantic.utils:version_info': 'pydantic.version:version_info',
#      10     'pydantic.error_wrappers:ValidationError': 'pydantic:ValidationError',
#    (...)
#      15     'pydantic.generics:GenericModel': 'pydantic.BaseModel',
#      16 }
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pydantic\warnings.py:5
#       1 """Pydantic-specific warnings."""
#       3 from __future__ import annotations as _annotations
# ----> 5 from .version import version_short
#       7 __all__ = (
#       8     'PydanticDeprecatedSince20',
#       9     'PydanticDeprecatedSince26',
#    (...)
#      18     'TypedDictExtraConfigWarning',
#      19 )
#      22 class PydanticDeprecationWarning(DeprecationWarning):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pydantic\version.py:7
#       3 from __future__ import annotations as _annotations
#       5 import sys
# ----> 7 from pydantic_core import __version__ as __pydantic_core_version__
#       9 __all__ = 'VERSION', 'version_info'
#      11 VERSION = '2.13.4'
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pydantic_core\__init__.py:6
#       3 import sys as _sys
#       4 from typing import Any as _Any
# ----> 6 from typing_extensions import Sentinel
#       8 from ._pydantic_core import (
#       9     ArgsKwargs,
#      10     MultiHostUrl,
#    (...)
#      29     to_jsonable_python,
#      30 )
#      31 from .core_schema import CoreConfig, CoreSchema, CoreSchemaType, ErrorType
#
# ImportError: cannot import name 'Sentinel' from 'typing_extensions' (C:\ProgramData\anaconda3\Lib\site-packages\typing_extensions.py)
